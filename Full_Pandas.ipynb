# %% [markdown]
# <a href="https://colab.research.google.com/github/scode4u/Basic_Pandas/blob/main/Full_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/Salaries.csv')
# Out:
#                 0      1       2       3       4       5          6       7   \
# rank          Prof   Prof    Prof    Prof    Prof    Prof  AssocProf    Prof
# discipline       B      A       A       A       B       A          A       A
# phd             56     12      23      40      20      20         20      18
# service         49      6      20      31      18      20         17      18
# sex           Male   Male    Male    Male    Male    Male       Male    Male
# salary      186960  93000  110515  131205  104800  122400      81285  126300
#
#                8      9   ...        68      69        70         71      72  \
# rank         Prof   Prof  ...  AsstProf    Prof  AsstProf  AssocProf    Prof
# discipline      A      A  ...         A       A         A          B       B
# phd            29     51  ...         4      28         8         12      24
# service        19     51  ...         2       7         3          9      15
# ...

# %%
df.head(2)

# df.tail(2)

# %%
df.describe() # print mean , max, std, count etc

# %%
df['phd']

# %%
df.index = ['first','second','third','fourth'] # change the index by giving name

# %%
df.index # print the indexes

# %%
df.columns # print the column name

# %%
df.T # transpose the data

# %%
df.sort_index(axis = 1 , ascending=False) # sort the column in descending order
# Out:
#        sex  service  salary       rank  phd discipline
# 0     Male       49  186960       Prof   56          B
# 1     Male        6   93000       Prof   12          A
# 2     Male       20  110515       Prof   23          A
# 3     Male       31  131205       Prof   40          A
# 4     Male       18  104800       Prof   20          B
# ..     ...      ...     ...        ...  ...        ...
# 73  Female       10  105450       Prof   18          B
# 74  Female        6  104542  AssocProf   19          B
# 75  Female       17  124312       Prof   17          B
# 76  Female       14  109954       Prof   28          A
# 77  Female       15  109646       Prof   23          A
#
# [78 rows x 6 columns]

# %%
# newdf = df.copy()  # copy all the data from existing data
# newdf

# %%
df = df.drop('phd', axis = 1 ) # drop the column

# %%
df.loc[[1,3],['phd']] # print the desired output
# Out:
#    phd
# 1   12
# 3   40

# %%
df.reset_index(drop = True, inplace = True)
df.head(3)
# Out:
#    rank discipline  service   sex  salary
# 0  Prof          B       49  Male  186960
# 1  Prof          A        6  Male   93000
# 2  Prof          A       20  Male  110515

# %%
df.size # print the shape of the data
# Out:
# <bound method DataFrame.info of          rank discipline  service     sex  salary
# 0        Prof          B       49    Male  186960
# 1        Prof          A        6    Male   93000
# 2        Prof          A       20    Male  110515
# 3        Prof          A       31    Male  131205
# 4        Prof          B       18    Male  104800
# ..        ...        ...      ...     ...     ...
# 73       Prof          B       10  Female  105450
# 74  AssocProf          B        6  Female  104542
# 75       Prof          B       17  Female  124312
# 76       Prof          A       14  Female  109954
# 77       Prof          A       15  Female  109646
#
# [78 rows x 5 columns]>

# %%
df.info # print the information of the data
